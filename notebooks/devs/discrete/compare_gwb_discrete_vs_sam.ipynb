# %%
# %reload_ext autoreload
# %autoreload 2
from importlib import reload

import os
import sys

import logging
import warnings
import numpy as np
import astropy as ap
import scipy as sp
import scipy.stats
import matplotlib as mpl
import matplotlib.pyplot as plt

import h5py
import tqdm.notebook as tqdm

import kalepy as kale
import kalepy.utils
import kalepy.plot

import holodeck as holo
import holodeck.sams
import holodeck.gravwaves
from holodeck import cosmo, utils, plot, discrete, sams, host_relations
from holodeck.constants import MSOL, PC, YR, MPC, GYR, SPLC

# Silence annoying numpy errors
np.seterr(divide='ignore', invalid='ignore', over='ignore')
warnings.filterwarnings("ignore", category=UserWarning)

# Plotting settings
mpl.rc('font', **{'family': 'serif', 'sans-serif': ['Times'], 'size': 15})
mpl.rc('lines', solid_capstyle='round')
mpl.rc('mathtext', fontset='cm')
plt.rcParams.update({'grid.alpha': 0.5})
mpl.style.use('default')   # avoid dark backgrounds from dark theme vscode

log = holo.log
log.setLevel(logging.INFO)

# %%
import compare_discrete

# %%
tmp = compare_discrete.create_dpops(allow_mbh0=True, mod_mmbulge=False, skip_evo=False, fsa_only=True, nreals=10)
all_dpops, tng_dpops, all_fsa_dpops, tng_fsa_dpops = tmp
# Out:
# Setting inspiral timescale tau = 1.0 Gyr.
# Setting fixed init binary sep = 10000.0 pc.
#
# Creating Discrete_Pop class instance 'fsa-mm-TNG100-1' with tau=3.15576e+16, fixed_sepa=3.0856775814913676e+22
#  fname=galaxy-mergers_TNG100-1_gas-100_dm-100_star-100_bh-001.hdf5
# fname = /Users/lblecha/holodeck/holodeck/data/galaxy-mergers_TNG100-1_gas-100_dm-100_star-100_bh-001.hdf5
# DEBUG: in population: self.scafa.min()=0.116345263, self.scafa.max()=1.0, np.median(self.scafa)=0.374999594
# num with scafa=1: 11
# gal_rads.min()=1.326763564100145e+21, gal_rads.max()=7.282709693743754e+23
# self.sepa.min()=3.0856775814913676e+22, self.sepa.max()=3.0856775814913676e+22
# No zero-mass BHs found in this merger tree file!
# self._use_mstar_tot_as_mbulge=False
# self.mbulge.min()=1.3306179568569139e+41, self.mbulge.max()=2.5837386273508947e+45
# self.mstar_tot.min()=2.2618726543725402e+41, self.mstar_tot.max()=3.765812268004308e+45
# No zero-mass BHs found in this merger tree file!
# 16:07:40 WARNING : Redefining mass ratio to be always <= 1. [population.py:_init]
# sample volume = 3.987e+79 [cgs] = 1.357e+06 [Mpc^3]; vol^(1/3) = 110.7 [Mpc]
# Read 3284 mergers from file.
# self.pop.sepa.min()=3.0856775814913676e+22, self.pop.sepa.max()=3.0856775814913676e+22, self.pop.sepa.shape=(3284,)
# self.pop.mstar_tot.min()=2.2618726543725402e+41, self.pop.mstar_tot.max()=3.765812268004308e+45, self.pop.mstar_tot.shape=(3284, 3)
# modeling fixed-total-time hardening...
# 16:07:40 INFO : calculating normalization exactly [hardening.py:__init__]
# self.pop.sepa.min()=3.0856775814913676e+22, self.pop.sepa.max()=3.0856775814913676e+22, self.pop.sepa.shape=(3284,)
# creating evolution instance and evolving it...
# self.evo._sample_volume=3.987492221854747e+79
# self.pop.sepa.min()=3.0856775814913676e+22, self.pop.sepa.max()=3.0856775814913676e+22, self.pop.sepa.shape=(3284,)
# self.pop.scafa.min()=0.116345263, self.pop.scafa.max()=1.0, self.pop.scafa.shape=(3284,)
# # with scafa=1 in pop: 11
# self.evo.sepa.min()=0.0, self.evo.sepa.max()=0.0, self.evo.sepa.shape=(3284, 100)
# self.evo.scafa.min()=0.0, self.evo.scafa.max()=0.0, self.evo.scafa.shape=(3284, 100)
# self.evo.scafa[:,-1].min()=0.0, self.evo.scafa[:,-1].max()=0.0, self.evo.scafa[:,-1].shape=(3284,)
# self.evo.scafa[:,0].min()=0.0, self.evo.scafa[:,0].max()=0.0, self.evo.scafa[:,0].shape=(3284,)
# coal.shape=(3284,), (3209,)
# self.evo.mass.shape=(3284, 100, 2)
# self.evo.sepa.min()=2106085230961.921, self.evo.sepa.max()=3.085677581491362e+22, self.evo.sepa.shape=(3284, 100)
# self.evo.scafa[:,-1].min()=0.2117878282366599, self.evo.scafa[:,-1].max()=1.0, self.evo.scafa[:,-1].shape=(3284,)
# self.evo.scafa[:,0].min()=0.116345263, self.evo.scafa[:,0].max()=1.0, self.evo.scafa[:,0].shape=(3284,)
# self.evo.scafa[coal,-1].min()=0.2117878282366599, self.evo.scafa[coal,-1].max()=0.9922443692772218, self.evo.scafa[coal,-1].shape=(3209,)
# self.evo.scafa[coal,0].min()=0.116345263, self.evo.scafa[coal,0].max()=0.922607588, self.evo.scafa[coal,0].shape=(3209,)
# self.evo.scafa[~coal,-1].min()=1.0, self.evo.scafa[~coal,-1].max()=1.0, self.evo.scafa[~coal,-1].shape=(75,)
# self.evo.scafa[~coal,0].min()=0.93139235, self.evo.scafa[~coal,0].max()=1.0, self.evo.scafa[~coal,0].shape=(75,)
# ix_a1_at_t0.shape=(11,)
# ix_a1.shape=(75,)
#
# sepa (coal) init step [PC]: min=10000, max=10000, med=10000
# sepa (~coal) init step [PC]: min=10000, max=10000, med=10000
# sepa (coal) final step [PC]: min=6.82536e-07, max=0.0021191, med=3.99911e-06
# sepa (~coal) final step [PC]: min=7.36582e-07, max=0.000354852, med=1.2169e-05
#
# scafa (coal) init step: min=0.116345, max=0.922608, med=0.375
# scafa (~coal) init step: min=0.931392, max=1, med=0.967376
# scafa (coal) final step: min=0.211788, max=0.992244, med=0.439754
# scafa (~coal) final step: min=1, max=1, med=1
#
# tlook (coal) init step: min=1.11538, max=13.0579, med=9.81208
# tlook (~coal) init step: min=0, max=0.986388, med=0.464371
# tlook (coal) final step: min=0.109622, max=12.0517, med=8.80748
# tlook (~coal) final step: min=-1.00602, max=-0.0172812, med=-0.540717
# dtlook (coal): min=0.999856, max=1.00619, med=1.00514
# dtlook (~coal): min=1.00116, max=1.00615, med=1.0045
#
# mass1 (coal) init step [MSOL]: min=1.18425e+06, max=6.97235e+09, med=9.21643e+06
# mass1 (~coal) init step [MSOL]: min=1.28535e+06, max=8.79682e+08, med=3.22328e+07
#
# mass2 (coal) init step [MSOL]: min=1.18256e+06, max=7.37799e+09, med=2.53009e+06
# mass2 (~coal) init step [MSOL]: min=1.28002e+06, max=5.79804e+08, med=8.077e+06
# GW frequencies:   0%|          | 0/40 [00:00<?, ?it/s]
# DEBUG: fobs_gw=1.976798990270053e-09
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3246,), gwb_harms.shape=(1,), num_pois.shape=(3246, 10), both.shape=(10,), temp_to_sort.shape=(3246, 10)
# idx_loud.shape=(3246, 10), loud.shape=(3246, 10)
# mchirp.shape=(3246,), redz.shape=(3246,), (3246, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.355e+06
# mchirp_loud: min=6.334e+08, max=2.493e+09, med=9.604e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.07e+07
# mpri_loud: min=7.305e+08, max=6.972e+09, med=2.417e+09
# mrat: min=0.0002257, max=1, med=0.5436
# mrat_loud: min=0.03719, max=0.9921, med=0.5552
# redz: min=5.071e-05, max=4.895, med=1.398
# redz_loud: min=0.04593, max=0.6924, med=0.1663
# sepa: min=0.002031, max=0.0869, med=0.007048
# sepa_loud: min=0.05259, max=0.08539, med=0.06003
#
# DEBUG: fobs_gw=3.953597980540106e-09
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3238,), gwb_harms.shape=(1,), num_pois.shape=(3238, 10), both.shape=(10,), temp_to_sort.shape=(3238, 10)
# idx_loud.shape=(3238, 10), loud.shape=(3238, 10)
# mchirp.shape=(3238,), redz.shape=(3238,), (3238, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.348e+06
# mchirp_loud: min=5.492e+08, max=2.493e+09, med=9.604e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=7.305e+08, max=6.972e+09, med=2.417e+09
# mrat: min=0.0002257, max=1, med=0.544
# mrat_loud: min=0.03719, max=0.9921, med=0.4722
# redz: min=0.0002751, max=4.301, med=1.343
# redz_loud: min=0.06989, max=0.6923, med=0.3394
# sepa: min=0.001374, max=0.05505, med=0.0045
# sepa_loud: min=0.03151, max=0.0538, med=0.03369
#
# DEBUG: fobs_gw=5.9303969708101585e-09
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3231,), gwb_harms.shape=(1,), num_pois.shape=(3231, 10), both.shape=(10,), temp_to_sort.shape=(3231, 10)
# idx_loud.shape=(3231, 10), loud.shape=(3231, 10)
# mchirp.shape=(3231,), redz.shape=(3231,), (3231, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=5.492e+08, max=2.493e+09, med=9.076e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.064e+07
# mpri_loud: min=9.193e+08, max=6.972e+09, med=1.793e+09
# mrat: min=0.0002257, max=1, med=0.5451
# mrat_loud: min=0.03719, max=0.9049, med=0.4207
# redz: min=0.0002921, max=4.028, med=1.328
# redz_loud: min=0.08453, max=0.9727, med=0.437
# sepa: min=0.001086, max=0.04206, med=0.003456
# sepa_loud: min=0.01862, max=0.04106, med=0.02478
#
# DEBUG: fobs_gw=7.907195961080211e-09
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3226,), gwb_harms.shape=(1,), num_pois.shape=(3226, 10), both.shape=(10,), temp_to_sort.shape=(3226, 10)
# idx_loud.shape=(3226, 10), loud.shape=(3226, 10)
# mchirp.shape=(3226,), redz.shape=(3226,), (3226, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.347e+06
# mchirp_loud: min=6.856e+07, max=1.499e+09, med=7.181e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.041e+08, max=2.541e+09, med=1.253e+09
# mrat: min=0.0002257, max=1, med=0.5447
# mrat_loud: min=0.2087, max=0.9921, med=0.6094
# redz: min=0.0005772, max=3.902, med=1.305
# redz_loud: min=0.008496, max=2.037, med=0.5782
# sepa: min=0.0009116, max=0.03474, med=0.002864
# sepa_loud: min=0.01058, max=0.02382, med=0.01823
#
# DEBUG: fobs_gw=9.883994951350265e-09
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3224,), gwb_harms.shape=(1,), num_pois.shape=(3224, 10), both.shape=(10,), temp_to_sort.shape=(3224, 10)
# idx_loud.shape=(3224, 10), loud.shape=(3224, 10)
# mchirp.shape=(3224,), redz.shape=(3224,), (3224, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.347e+06
# mchirp_loud: min=6.856e+07, max=1.252e+09, med=6.004e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.041e+08, max=2.417e+09, med=8.747e+08
# mrat: min=0.0002257, max=1, med=0.5455
# mrat_loud: min=0.2087, max=0.9622, med=0.6912
# redz: min=0.0001403, max=3.831, med=1.287
# redz_loud: min=0.008284, max=2.037, med=0.8398
# sepa: min=0.0007933, max=0.02994, med=0.002471
# sepa_loud: min=0.009119, max=0.02053, med=0.01229
#
# DEBUG: fobs_gw=1.1860793941620317e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3223,), gwb_harms.shape=(1,), num_pois.shape=(3223, 10), both.shape=(10,), temp_to_sort.shape=(3223, 10)
# idx_loud.shape=(3223, 10), loud.shape=(3223, 10)
# mchirp.shape=(3223,), redz.shape=(3223,), (3223, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.346e+06
# mchirp_loud: min=1.576e+08, max=1.499e+09, med=5.411e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=2.895e+08, max=2.541e+09, med=7.452e+08
# mrat: min=0.0002257, max=1, med=0.5458
# mrat_loud: min=0.2087, max=0.997, med=0.5751
# redz: min=4.283e-05, max=3.793, med=1.281
# redz_loud: min=0.06974, max=2.037, med=0.7612
# sepa: min=0.0007062, max=0.02651, med=0.002192
# sepa_loud: min=0.007991, max=0.01818, med=0.01073
#
# DEBUG: fobs_gw=1.3837592931890369e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3218,), gwb_harms.shape=(1,), num_pois.shape=(3218, 10), both.shape=(10,), temp_to_sort.shape=(3218, 10)
# idx_loud.shape=(3218, 10), loud.shape=(3218, 10)
# mchirp.shape=(3218,), redz.shape=(3218,), (3218, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.347e+06
# mchirp_loud: min=1.208e+08, max=1.499e+09, med=4.571e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.499e+08, max=2.541e+09, med=7.07e+08
# mrat: min=0.0002257, max=1, med=0.5468
# mrat_loud: min=0.2087, max=0.997, med=0.626
# redz: min=0.0001179, max=3.769, med=1.28
# redz_loud: min=0.04562, max=2.037, med=0.7066
# sepa: min=0.0006394, max=0.02393, med=0.001978
# sepa_loud: min=0.006885, max=0.01461, med=0.009057
#
# DEBUG: fobs_gw=1.5814391922160423e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3216,), gwb_harms.shape=(1,), num_pois.shape=(3216, 10), both.shape=(10,), temp_to_sort.shape=(3216, 10)
# idx_loud.shape=(3216, 10), loud.shape=(3216, 10)
# mchirp.shape=(3216,), redz.shape=(3216,), (3216, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.348e+06
# mchirp_loud: min=1.866e+08, max=9.539e+08, med=4.105e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=3.484e+08, max=1.784e+09, med=6.541e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.2087, max=0.997, med=0.5722
# redz: min=0.001188, max=3.757, med=1.279
# redz_loud: min=0.1245, max=2.241, med=0.9928
# sepa: min=0.0005859, max=0.02189, med=0.001811
# sepa_loud: min=0.005363, max=0.01251, med=0.007746
#
# DEBUG: fobs_gw=1.7791190912430476e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3216,), gwb_harms.shape=(1,), num_pois.shape=(3216, 10), both.shape=(10,), temp_to_sort.shape=(3216, 10)
# idx_loud.shape=(3216, 10), loud.shape=(3216, 10)
# mchirp.shape=(3216,), redz.shape=(3216,), (3216, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.348e+06
# mchirp_loud: min=1.143e+08, max=8.132e+08, med=3.598e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.659e+08, max=1.065e+09, med=5.85e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.1235, max=0.9943, med=0.5987
# redz: min=0.0001883, max=3.747, med=1.278
# redz_loud: min=0.008057, max=1.856, med=0.8704
# sepa: min=0.0005425, max=0.02024, med=0.001676
# sepa_loud: min=0.005562, max=0.01054, med=0.007113
#
# DEBUG: fobs_gw=1.976798990270053e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3215,), gwb_harms.shape=(1,), num_pois.shape=(3215, 10), both.shape=(10,), temp_to_sort.shape=(3215, 10)
# idx_loud.shape=(3215, 10), loud.shape=(3215, 10)
# mchirp.shape=(3215,), redz.shape=(3215,), (3215, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=1.282e+08, max=8.102e+08, med=3.235e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.659e+08, max=1.784e+09, med=5.122e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.2087, max=0.9992, med=0.5883
# redz: min=0.0001268, max=3.741, med=1.277
# redz_loud: min=0.06001, max=2.241, med=0.7175
# sepa: min=0.0005061, max=0.01886, med=0.001563
# sepa_loud: min=0.004622, max=0.01078, med=0.006674
#
# DEBUG: fobs_gw=2.174478889297058e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3214,), gwb_harms.shape=(1,), num_pois.shape=(3214, 10), both.shape=(10,), temp_to_sort.shape=(3214, 10)
# idx_loud.shape=(3214, 10), loud.shape=(3214, 10)
# mchirp.shape=(3214,), redz.shape=(3214,), (3214, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.35e+06
# mchirp_loud: min=1.202e+08, max=1.499e+09, med=2.894e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.892e+08, max=2.541e+09, med=4.89e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.1235, max=0.9992, med=0.5048
# redz: min=0.001368, max=3.737, med=1.277
# redz_loud: min=0.1502, max=2.241, med=1.013
# sepa: min=0.0004752, max=0.0177, med=0.001467
# sepa_loud: min=0.004015, max=0.01081, med=0.005825
#
# DEBUG: fobs_gw=2.3721587883240634e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3214,), gwb_harms.shape=(1,), num_pois.shape=(3214, 10), both.shape=(10,), temp_to_sort.shape=(3214, 10)
# idx_loud.shape=(3214, 10), loud.shape=(3214, 10)
# mchirp.shape=(3214,), redz.shape=(3214,), (3214, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.35e+06
# mchirp_loud: min=1.723e+08, max=7.181e+08, med=2.746e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=2.603e+08, max=1.43e+09, med=5.376e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.1291, max=0.997, med=0.4019
# redz: min=0.0009451, max=3.734, med=1.276
# redz_loud: min=0.1245, max=2.241, med=0.8703
# sepa: min=0.0004486, max=0.0167, med=0.001385
# sepa_loud: min=0.003964, max=0.008003, med=0.005448
#
# DEBUG: fobs_gw=2.5698386873510688e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3214,), gwb_harms.shape=(1,), num_pois.shape=(3214, 10), both.shape=(10,), temp_to_sort.shape=(3214, 10)
# idx_loud.shape=(3214, 10), loud.shape=(3214, 10)
# mchirp.shape=(3214,), redz.shape=(3214,), (3214, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.35e+06
# mchirp_loud: min=1.1e+08, max=8.567e+08, med=2.404e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.573e+08, max=1.23e+09, med=3.54e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.1235, max=0.9854, med=0.6181
# redz: min=0.0005563, max=3.731, med=1.276
# redz_loud: min=0.1347, max=2.448, med=1.013
# sepa: min=0.0004254, max=0.01584, med=0.001313
# sepa_loud: min=0.00317, max=0.008565, med=0.004877
#
# DEBUG: fobs_gw=2.7675185863780738e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3214,), gwb_harms.shape=(1,), num_pois.shape=(3214, 10), both.shape=(10,), temp_to_sort.shape=(3214, 10)
# idx_loud.shape=(3214, 10), loud.shape=(3214, 10)
# mchirp.shape=(3214,), redz.shape=(3214,), (3214, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.35e+06
# mchirp_loud: min=1.176e+08, max=4.274e+08, med=2.171e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.688e+08, max=9.155e+08, med=3.664e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.1043, max=0.9992, med=0.5617
# redz: min=0.0001967, max=3.729, med=1.275
# redz_loud: min=0.1347, max=2.583, med=0.8704
# sepa: min=0.000405, max=0.01507, med=0.00125
# sepa_loud: min=0.002819, max=0.006389, med=0.004542
#
# DEBUG: fobs_gw=2.9651984854050792e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=7.347e+07, max=5.986e+08, med=2.045e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=9.003e+07, max=1.065e+09, med=3.565e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.1187, max=0.9992, med=0.5822
# redz: min=0.0009284, max=3.728, med=1.275
# redz_loud: min=0.0697, max=2.448, med=1.013
# sepa: min=0.0003869, max=0.0144, med=0.001194
# sepa_loud: min=0.002881, max=0.00571, med=0.004076
#
# DEBUG: fobs_gw=3.1628783844320846e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=7.347e+07, max=4.274e+08, med=2.143e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=9.003e+07, max=1.065e+09, med=4.229e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.03918, max=0.9992, med=0.3882
# redz: min=0.0005039, max=3.727, med=1.275
# redz_loud: min=0.09425, max=2.583, med=1.179
# sepa: min=0.0003706, max=0.01379, med=0.001144
# sepa_loud: min=0.002737, max=0.005133, med=0.003802
#
# DEBUG: fobs_gw=3.3605582834590896e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=5.838e+07, max=4.14e+08, med=1.899e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=8.258e+07, max=1.065e+09, med=3.206e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.1187, max=0.9786, med=0.6149
# redz: min=0.0002945, max=3.727, med=1.275
# redz_loud: min=0.09425, max=2.344, med=0.9766
# sepa: min=0.000356, max=0.01324, med=0.001098
# sepa_loud: min=0.002531, max=0.005065, med=0.003678
#
# DEBUG: fobs_gw=3.558238182486095e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=6.994e+07, max=5.986e+08, med=1.819e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.097e+08, max=9.475e+08, med=3.254e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.0931, max=0.9786, med=0.5765
# redz: min=0.000239, max=3.726, med=1.275
# redz_loud: min=0.1764, max=2.583, med=1.013
# sepa: min=0.0003427, max=0.01275, med=0.001057
# sepa_loud: min=0.002436, max=0.005403, med=0.003522
#
# DEBUG: fobs_gw=3.7559180815131e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=3.901e+07, max=7.019e+08, med=1.651e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=1.201e+08, max=2.731e+09, med=3.34e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.0032, max=0.9854, med=0.4699
# redz: min=0.0001865, max=3.725, med=1.275
# redz_loud: min=0.05993, max=2.344, med=1.054
# sepa: min=0.0003306, max=0.0123, med=0.00102
# sepa_loud: min=0.002321, max=0.008474, med=0.003329
#
# DEBUG: fobs_gw=3.953597980540106e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=2.797e+07, max=5.986e+08, med=1.033e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=3.645e+07, max=7.378e+09, med=2.323e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.0003279, max=0.995, med=0.5864
# redz: min=0.0001367, max=3.725, med=1.275
# redz_loud: min=0.0942, max=2.583, med=0.8857
# sepa: min=0.0003195, max=0.01188, med=0.0009855
# sepa_loud: min=0.002182, max=0.01188, med=0.00302
#
# DEBUG: fobs_gw=4.151277879567111e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=6.714e+07, max=6.708e+08, med=1.134e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=9.923e+07, max=2.546e+09, med=2.063e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.004889, max=0.9824, med=0.5043
# redz: min=8.929e-05, max=3.724, med=1.275
# redz_loud: min=0.2415, max=2.344, med=0.9765
# sepa: min=0.0003093, max=0.0115, med=0.000954
# sepa_loud: min=0.001864, max=0.005734, med=0.002834
#
# DEBUG: fobs_gw=4.348957778594116e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=5.838e+07, max=3.624e+08, med=1.211e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=8.258e+07, max=2.546e+09, med=2.84e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.004889, max=0.9626, med=0.4705
# redz: min=4.413e-05, max=3.724, med=1.275
# redz_loud: min=0.1346, max=2.583, med=0.855
# sepa: min=0.0002999, max=0.01115, med=0.0009249
# sepa_loud: min=0.002114, max=0.005553, med=0.002838
#
# DEBUG: fobs_gw=4.546637677621122e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3213,), gwb_harms.shape=(1,), num_pois.shape=(3213, 10), both.shape=(10,), temp_to_sort.shape=(3213, 10)
# idx_loud.shape=(3213, 10), loud.shape=(3213, 10)
# mchirp.shape=(3213,), redz.shape=(3213,), (3213, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.349e+06
# mchirp_loud: min=4.033e+07, max=4.765e+08, med=1.211e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=7.869e+07, max=9.475e+08, med=2.518e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.05801, max=0.9824, med=0.5759
# redz: min=9.814e-07, max=3.724, med=1.275
# redz_loud: min=0.2086, max=2.097, med=0.9405
# sepa: min=0.0002911, max=0.01083, med=0.0008979
# sepa_loud: min=0.001699, max=0.003984, med=0.002724
#
# DEBUG: fobs_gw=4.744317576648127e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3212,), gwb_harms.shape=(1,), num_pois.shape=(3212, 10), both.shape=(10,), temp_to_sort.shape=(3212, 10)
# idx_loud.shape=(3212, 10), loud.shape=(3212, 10)
# mchirp.shape=(3212,), redz.shape=(3212,), (3212, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.35e+06
# mchirp_loud: min=3.656e+07, max=3.655e+08, med=9.51e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.063e+07
# mpri_loud: min=5.207e+07, max=9.042e+08, med=2.258e+08
# mrat: min=0.0002257, max=1, med=0.5465
# mrat_loud: min=0.04958, max=0.9786, med=0.3295
# redz: min=8.397e-06, max=3.724, med=1.274
# redz_loud: min=0.06961, max=2.24, med=0.8094
# sepa: min=0.000283, max=0.01052, med=0.0008727
# sepa_loud: min=0.001863, max=0.004577, med=0.002619
#
# DEBUG: fobs_gw=4.941997475675132e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3211,), gwb_harms.shape=(1,), num_pois.shape=(3211, 10), both.shape=(10,), temp_to_sort.shape=(3211, 10)
# idx_loud.shape=(3211, 10), loud.shape=(3211, 10)
# mchirp.shape=(3211,), redz.shape=(3211,), (3211, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.351e+06
# mchirp_loud: min=3.743e+07, max=2.475e+08, med=1.035e+08
# mpri: min=1.191e+06, max=7.378e+09, med=1.064e+07
# mpri_loud: min=4.615e+07, max=1.014e+09, med=2.506e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.02581, max=0.9907, med=0.326
# redz: min=0.0001236, max=3.723, med=1.274
# redz_loud: min=0.1977, max=2.241, med=1.033
# sepa: min=0.0002754, max=0.01024, med=0.0008492
# sepa_loud: min=0.001607, max=0.003616, med=0.00243
#
# DEBUG: fobs_gw=5.1396773747021376e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3211,), gwb_harms.shape=(1,), num_pois.shape=(3211, 10), both.shape=(10,), temp_to_sort.shape=(3211, 10)
# idx_loud.shape=(3211, 10), loud.shape=(3211, 10)
# mchirp.shape=(3211,), redz.shape=(3211,), (3211, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.351e+06
# mchirp_loud: min=2.797e+07, max=2.971e+08, med=8.75e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.064e+07
# mpri_loud: min=3.645e+07, max=8.343e+08, med=1.488e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.01108, max=0.9854, med=0.3856
# redz: min=7.714e-05, max=3.723, med=1.274
# redz_loud: min=0.09418, max=2.24, med=1.124
# sepa: min=0.0002683, max=0.009976, med=0.0008273
# sepa_loud: min=0.001484, max=0.003179, med=0.002273
#
# DEBUG: fobs_gw=5.3373572737291426e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3211,), gwb_harms.shape=(1,), num_pois.shape=(3211, 10), both.shape=(10,), temp_to_sort.shape=(3211, 10)
# idx_loud.shape=(3211, 10), loud.shape=(3211, 10)
# mchirp.shape=(3211,), redz.shape=(3211,), (3211, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.351e+06
# mchirp_loud: min=3.775e+07, max=3.541e+08, med=7.568e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.064e+07
# mpri_loud: min=7.22e+07, max=7.452e+08, med=1.572e+08
# mrat: min=0.0002257, max=1, med=0.5466
# mrat_loud: min=0.04958, max=0.9626, med=0.306
# redz: min=3.242e-05, max=3.723, med=1.274
# redz_loud: min=0.1765, max=2.239, med=1.013
# sepa: min=0.0002617, max=0.009728, med=0.0008068
# sepa_loud: min=0.001392, max=0.004661, med=0.002144
#
# DEBUG: fobs_gw=5.5350371727561476e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=4.563e+07, max=2.701e+08, med=8.201e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=7.036e+07, max=8.862e+08, med=1.638e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.01285, max=0.9824, med=0.3119
# redz: min=0.007949, max=3.723, med=1.274
# redz_loud: min=0.1764, max=2.097, med=1.013
# sepa: min=0.0002554, max=0.009495, med=0.0007867
# sepa_loud: min=0.001647, max=0.003766, med=0.002083
#
# DEBUG: fobs_gw=5.7327170717831533e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=3.966e+07, max=4.672e+08, med=8.355e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=5.546e+07, max=1.043e+09, med=1.506e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.01156, max=0.9799, med=0.3657
# redz: min=0.007945, max=3.723, med=1.274
# redz_loud: min=0.2085, max=2.655, med=1.205
# sepa: min=0.0002495, max=0.009276, med=0.0007686
# sepa_loud: min=0.001141, max=0.003355, med=0.001973
#
# DEBUG: fobs_gw=5.9303969708101584e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=2.797e+07, max=4.033e+08, med=7.59e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=3.645e+07, max=7.452e+08, med=1.445e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.03918, max=0.997, med=0.4334
# redz: min=0.007943, max=3.723, med=1.274
# redz_loud: min=0.09418, max=2.582, med=1.053
# sepa: min=0.0002439, max=0.009069, med=0.0007514
# sepa_loud: min=0.001201, max=0.003376, med=0.001898
#
# DEBUG: fobs_gw=6.128076869837163e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=2.25e+07, max=1.125e+08, med=5.854e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=2.778e+07, max=1.014e+09, med=1.216e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.02581, max=0.9379, med=0.4229
# redz: min=0.007942, max=3.723, med=1.274
# redz_loud: min=0.09417, max=2.977, med=1.179
# sepa: min=0.0002386, max=0.008873, med=0.0007351
# sepa_loud: min=0.001018, max=0.002396, med=0.001725
#
# DEBUG: fobs_gw=6.325756768864169e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=1.361e+07, max=2.475e+08, med=6.826e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=2.07e+07, max=1.356e+09, med=1.298e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.005538, max=0.9992, med=0.4007
# redz: min=0.00794, max=3.723, med=1.274
# redz_loud: min=0.06956, max=2.24, med=0.9722
# sepa: min=0.0002336, max=0.008687, med=0.0007197
# sepa_loud: min=0.00122, max=0.003067, med=0.001818
#
# DEBUG: fobs_gw=6.523436667891175e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=2.163e+07, max=2.621e+08, med=6.323e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=3.47e+07, max=1.646e+09, med=1.464e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.002023, max=0.9977, med=0.3674
# redz: min=0.007938, max=3.723, med=1.274
# redz_loud: min=0.06958, max=2.097, med=1.166
# sepa: min=0.0002289, max=0.00851, med=0.0007051
# sepa_loud: min=0.001238, max=0.004129, med=0.001769
#
# DEBUG: fobs_gw=6.721116566918179e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=3.35e+07, max=2.617e+08, med=6.637e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=4.908e+07, max=3.127e+09, med=1.365e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.0006178, max=0.9824, med=0.3006
# redz: min=0.007937, max=3.722, med=1.274
# redz_loud: min=0.3932, max=2.582, med=1.095
# sepa: min=0.0002244, max=0.008343, med=0.0006912
# sepa_loud: min=0.001028, max=0.004056, med=0.001759
#
# DEBUG: fobs_gw=6.918796465945185e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=8.943e+06, max=1.942e+08, med=5.389e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=1.656e+07, max=3.127e+09, med=1.281e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.0006178, max=0.9992, med=0.3103
# redz: min=0.007936, max=3.722, med=1.274
# redz_loud: min=0.05986, max=2.977, med=1.179
# sepa: min=0.0002201, max=0.008183, med=0.000678
# sepa_loud: min=0.0009386, max=0.003978, med=0.001561
#
# DEBUG: fobs_gw=7.11647636497219e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=2.012e+07, max=2.922e+08, med=5.895e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=2.812e+07, max=1.508e+09, med=1.553e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.002531, max=0.9977, med=0.3655
# redz: min=0.007934, max=3.722, med=1.274
# redz_loud: min=0.1092, max=2.977, med=1.179
# sepa: min=0.000216, max=0.008031, med=0.0006654
# sepa_loud: min=0.0009161, max=0.003557, med=0.001637
#
# DEBUG: fobs_gw=7.314156263999195e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=2.913e+07, max=2.792e+08, med=5.604e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=4.945e+07, max=1.508e+09, med=1.329e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.002531, max=0.9463, med=0.2728
# redz: min=0.007933, max=3.722, med=1.274
# redz_loud: min=0.494, max=2.655, med=1.327
# sepa: min=0.0002121, max=0.007885, med=0.0006533
# sepa_loud: min=0.0009682, max=0.003492, med=0.00147
#
# DEBUG: fobs_gw=7.5118361630262e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=1.909e+07, max=2.56e+08, med=5.119e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=2.279e+07, max=2.754e+09, med=1.087e+08
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.0004314, max=0.9805, med=0.4534
# redz: min=0.007931, max=3.722, med=1.274
# redz_loud: min=0.06004, max=2.977, med=1.074
# sepa: min=0.0002084, max=0.007746, med=0.0006418
# sepa_loud: min=0.0008885, max=0.005837, med=0.001476
#
# DEBUG: fobs_gw=7.709516062053206e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=2.042e+07, max=1.825e+08, med=4.229e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=3.167e+07, max=2.546e+09, med=9.293e+07
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.004889, max=0.9117, med=0.3719
# redz: min=0.00793, max=3.722, med=1.274
# redz_loud: min=0.2865, max=2.096, med=1.166
# sepa: min=0.0002048, max=0.007613, med=0.0006308
# sepa_loud: min=0.0008613, max=0.003791, med=0.001351
#
# DEBUG: fobs_gw=7.907195961080212e-08
#
# *** DEBUG *** mrat.min()=0.00022569315672513172, 0.999960413329724
# temp.shape=(3209,), gwb_harms.shape=(1,), num_pois.shape=(3209, 10), both.shape=(10,), temp_to_sort.shape=(3209, 10)
# idx_loud.shape=(3209, 10), loud.shape=(3209, 10)
# mchirp.shape=(3209,), redz.shape=(3209,), (3209, 10)=
# mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# loud.shape=(5, 10), mchirp_loud.shape=(5, 10), redz_loud.shape=(5, 10)
# mchirp: min=1.035e+06, max=2.493e+09, med=4.354e+06
# mchirp_loud: min=1.525e+07, max=1.017e+08, med=4.455e+07
# mpri: min=1.191e+06, max=7.378e+09, med=1.065e+07
# mpri_loud: min=2.758e+07, max=3.127e+09, med=9.198e+07
# mrat: min=0.0002257, max=1, med=0.5463
# mrat_loud: min=0.0006178, max=0.9977, med=0.4443
# redz: min=0.007929, max=3.722, med=1.274
# redz_loud: min=0.09416, max=2.24, med=1.231
# sepa: min=0.0002014, max=0.007486, med=0.0006203
# sepa_loud: min=0.0008468, max=0.00364, med=0.001329
# TNG100-1 dpop_attrs: galaxy-mergers_TNG100-1_gas-100_dm-100_star-100_bh-001.hdf5 /orange/lblecha/IllustrisTNG/Runs/TNG100-1/output/ b 2.5

# %%
print(len(all_fsa_dpops))
# Out:
# 1

# %%
# ---- Define the GWB frequencies
freqs, freqs_edges = utils.pta_freqs()

# %%
print("creating SAM using Galaxy Pair Fraction (GPF) + Galaxy Merger Timescale (GMT)...")

sam = sams.Semi_Analytic_Model(gpf = sams.GPF_Power_Law())

print("    ...calculating hardening")
hard = holo.hardening.Fixed_Time_2PL_SAM(sam, all_fsa_dpops[0].tau, sepa_init=1.0e4*PC)
print("    ...creating gwb")
#gwb_sam = sam.gwb_new(freqs_edges, hard, realize=50)
gwb_sam = sam.gwb(freqs_edges, hard, realize=50, loudest=10, params=True)
# Out:
# creating SAM using Galaxy Pair Fraction (GPF) + Galaxy Merger Timescale (GMT)...
# 16:07:46 INFO : Galaxy pair-fraction provided, using galaxy pair-fraction and merger-time. [sam.py:__init__]
#     ...calculating hardening
#     ...creating gwb
#
#  *** in _static_binary_density() ***
#
# ** using GPF in _ndens_gal() **
# GPF_USES_MTOT=False, GMT_USES_MTOT=False, GSMF_USES_MTOT=False
# self._gpf(mass_gpf, mstar_rat, redz).shape=(91, 81, 101), self._gpf(mass_gpf, mstar_rat, redz).min()=0.03335999733439941, self._gpf(mass_gpf, mstar_rat, redz).max()=0.22698277091741006
# gal_merger_rate.shape=(91, 81, 101), gal_merger_rate.max()=4.3373311313467944e-17, gal_merger_rate.min()=1.922987182177158e-18
# 16:07:47 INFO : Adding MMbulge scatter (2.8000e-01) [sam.py:static_binary_density]
# 16:07:47 INFO : 	dens bef: (5.35e-282, 1.12e-124, 4.81e-26, 1.36e-03, 1.59e-02, 2.90e-02, 6.20e-02) [sam.py:static_binary_density]
# 16:08:06 INFO : Scatter added after 19.040027 sec [sam.py:static_binary_density]
# 16:08:06 INFO : 	dens aft: (3.84e-28, 2.75e-14, 1.05e-08, 1.40e-03, 1.59e-02, 2.88e-02, 5.98e-02) [sam.py:static_binary_density]
# 16:08:06 INFO : 	mass: 7.10e-02 ==> 7.12e-02 || change = 1.9219e-03 [sam.py:static_binary_density]
# 16:08:06 INFO : zeroing out 2.95e+05/7.44e+05 = 3.96e-01 bins stalled from GMT [sam.py:static_binary_density]

# %%
print(len(gwb_sam))
# Out:
# 4

# %%
print(len(gwb_sam[0]), len(gwb_sam[1]), len(gwb_sam[2]), len(gwb_sam[3])) #, len(gwb_sam_new))
print(gwb_sam[0].shape) # hc2ss: [nfreqs, nreals, nloudest]
print(gwb_sam[1].shape) # hc2bg: [nfreqs, nreals]
print(gwb_sam[2].shape) # sspars: [nsspars, nfreqs, nreals, nloudest]
print(gwb_sam[3].shape) # bgpars: [nbgpars, nfreqs, nreals]
# sspars:
# sspar[0,ff,rr,ll] = mt[mm]
# sspar[1,ff,rr,ll] = mr[qq]
# sspar[2,ff,rr,ll] = rz[zz]
# sspar[3,ff,rr,ll] = redz_final[mm,qq,zz,ff]
# bgpars: 
# bgpar[0,ff,rr] = m_bg/sum_bg # bg avg mass
# bgpar[1,ff,rr] = q_bg/sum_bg # bg avg ratio
# bgpar[2,ff,rr] = z_bg/sum_bg # bg avg redshift
# bgpar[3,ff,rr] = zfinal_bg/sum_bg # bg avg redshift after hardening
# bgpar[4,ff,rr] = dcom_bg/sum_bg # bg avg comoving distance after hardening
# bgpar[5,ff,rr] = sepa_bg/sum_bg # bg avg binary separation after hardening
# bgpar[6,ff,rr] = angs_bg/sum_bg # bg avg binary angular separation after hardening
# Out:
# 40 40 4 7
# (40, 50, 10)
# (40, 50)
# (4, 40, 50, 10)
# (7, 40, 50)

# %%
foo = [np.zeros((3,2,4))]*4
print(len(foo), foo[0].shape)

# %%
gwb_sam_L100 = sam.gwb(freqs_edges, hard, realize=50, loudest=100, params=True)
gwb_sam_new = sam.gwb_new(freqs_edges, hard, realize=50)

# %%
plt.xscale('log')
plt.yscale('log')
for ll in range(10):
    plt.plot(freqs, np.mean(gwb_sam[2][0,:,:,ll],axis=1)/MSOL,'.') # mtot of 10 loudest sources in each freq bin, avg over nreals
plt.plot(freqs, gwb_sam[3][0,:,:]/MSOL,'k',lw=0.5,alpha=0.1); # avg mtot of bg sources for each freq for each real

# %%
for d in all_dpops:
    print(f"{d.evo.scafa.shape=}, {d.evo.tlook.shape=}, {d.evo.sepa.shape=}, {d.evo.mass.shape=}")

# %%
print("creating 'no-GPF' SAM using Galaxy Merger Rate (GMR) "
      "    (uses galaxy merger rates directly from RG15 instead of GPF+GMT)...")

sam_no_gpf = sams.Semi_Analytic_Model()

print("    ...calculating hardening for no-GPF SAM")
hard_no_gpf = holo.hardening.Fixed_Time_2PL_SAM(sam_no_gpf, all_fsa_dpops[0].tau, sepa_init=1.0e4*PC)
print("    ...creating gwb for no-GPF SAM")
gwb_sam_no_gpf = sam_no_gpf.gwb_new(freqs_edges, hard_no_gpf, realize=50)

# %%
#def get_dpop_amplitudes_at_freq(d,f):
    
#    freqs = np.array([1/YR, 1/(3*YR), 1/(10*YR)])
#    amps = np.zeros_like(freqs)
    
#    for i,f in enumerate(freqs):
#        # ---- find frequency bins closest to chosen freqs
#        idx = np.where(np.abs(d.freqs-f)==np.abs(d.freqs-f).min())[0]
#        amps[i] = d.gwb.back[idx,:].flatten()

#    return amps
        
##for d in tng_dpops + tng_fsa_dpops: #all_sim_dpops + all_fsa_dpops:
##for d in all_hires_fid_and_fsa_dpops: 
##for d in all_fsa_dpops: 
#for d in all_dpops: 
#    d.get_amplitudes_at_freqs()
#for d in all_fsa_dpops: 
#    d.get_amplitudes_at_freqs()

### this is sketch. only works if freqs is same for all dpops and for sam
#ayr_sam = gwb_sam[d.idx_ayr,:].flatten()
#a3yr_sam = gwb_sam[d.idx_a3yr,:].flatten()
#a10yr_sam = gwb_sam[d.idx_a10yr,:].flatten()

#ayr_sam_no_gpf = gwb_sam_no_gpf[d.idx_ayr,:].flatten()
#a3yr_sam_no_gpf = gwb_sam_no_gpf[d.idx_a3yr,:].flatten()
#a10yr_sam_no_gpf = gwb_sam_no_gpf[d.idx_a10yr,:].flatten()

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, sharex=True, figsize=[10,10])

freqs_to_plot = np.array([1/YR, 1/(3*YR), 1/(10*YR)])
amps = np.zeros_like(freqs)
    
for i,f in enumerate(freqs_to_plot):
    idx = np.where(np.abs(freqs-f)==np.abs(freqs-f).min())[0]
    amp_sam = gwb_sam[idx,:].flatten()
    amp_sam_no_gpf = gwb_sam_no_gpf[idx,:].flatten()

    if i==freqs_to_plot.size-1:
        axs[i].set(xlabel=r'$\log_{10}(A_\mathrm{yr})$')
    axs[i].set(ylabel='Probability Density')
    axs[i].grid(alpha=0.2)
    kale.dist1d(np.log10(amp_sam), density=True, hist=False, confidence=True, carpet=False, 
                lw=4, color='k', label='SAM',ax=axs[i])
    kale.dist1d(np.log10(amp_sam_no_gpf), density=True, hist=False, confidence=True, carpet=False, 
                lw=4, color='orchid', label='SAM (no GPF)', ax=axs[i])
    #for i in np.arange(len(tng_dpops)):
    for d in all_fsa_dpops:
        if np.any(d.freqs!=freqs):
            print(f"WARNING: SAM and sim have different frequency arrays.")
            idx_sim = np.where(np.abs(d.freqs-f)==np.abs(d.freqs-f).min())[0]
        else:
            idx_sim = idx    
        amp_sim = d.gwb.both[idx_sim,:].flatten()
    
        if np.any(~np.isfinite(amp_sim)):
            print(f"skipping {d.lbl} ({amp_sim.min()}, {amp_sim.max()})")
        else:
            print(f"{d.lbl} ({amp_sim.min()}, {amp_sim.max()})")
            kale.dist1d(np.log10(amp_sim), density=True, hist=False, confidence=False, carpet=False, 
                        label=d.lbl, lw=d.lw, color=d.color,alpha=0.5, ax=axs[i])
    #for d in [all_fsa_dpops[0],all_fsa_dpops[2]]:
    #    if np.any(~np.isfinite(d.ayr)):
    #        print(f"skipping {d.lbl} ({d.ayr.min()}, {d.ayr.max()})")
    #    else:
    #        print(f"{d.lbl} ({d.ayr.min()}, {d.ayr.max()})")
    #        kale.dist1d(np.log10(d.ayr), density=True, hist=False, confidence=False, carpet=False, 
    #                    label=d.lbl, lw=d.lw, color=d.color,alpha=0.5, ax=axs[i])

    axs[i].set(title=f"Comparison of GWB amplitudes at f={f*YR:.1g} YR")
    axs[i].legend()
#fig.savefig(f'compare_dpops_tau{tau/(1e9*YR):.1f}_A1yr.png')
#plt.show()

# %%
def __plot_gwb(fobs, gwb, hc_ss=None, bglabel=None, sslabel=None, **kwargs):
    xx = fobs * YR
    fig, ax = figax(
        xlabel=LABEL_GW_FREQUENCY_YR,
        ylabel=LABEL_CHARACTERISTIC_STRAIN
    )
    if(hc_ss is not None):
        draw_ss_and_gwb(ax, xx, hc_ss, gwb, sslabel=sslabel,
                        bglabel=bglabel, **kwargs)
    else:
        draw_gwb(ax, xx, gwb, **kwargs)
    _twin_hz(ax)
    return fig

def __draw_gwb(ax, xx, gwb, nsamp=10, color=None, label=None, **kwargs):
    if color is None:
        color = ax._get_lines.get_next_color()

    kw_plot = kwargs.pop('plot', {})
    kw_plot.setdefault('color', color)
    hh = __draw_med_conf(ax, xx, gwb, plot=kw_plot, label=label, **kwargs)
    if (nsamp is not None) and (nsamp > 0):
        nsamp_max = gwb.shape[1]
        idx = np.random.choice(nsamp_max, np.min([nsamp, nsamp_max]), replace=False)
        for ii in idx:
            ax.plot(xx, gwb[:, ii], color=color, alpha=0.25, lw=1.0, ls='-')

    return hh

def __draw_med_conf(ax, xx, vals, fracs=[0.50, 0.90], weights=None, plot={}, 
                    fill={}, filter=False, label=None, lw=1.0, ls='-'):
    #plot.setdefault('alpha', 0.75)
    #fill.setdefault('alpha', 0.2)
    plot.setdefault('alpha', 0.75)
    fill.setdefault('alpha', 0.2)
    percs = np.atleast_1d(fracs)
    assert np.all((0.0 <= percs) & (percs <= 1.0))

    # center the target percentages into pairs around 50%, e.g.  68 ==> [16,84]
    inter_percs = [[0.5-pp/2, 0.5+pp/2] for pp in percs]
    # Add the median value (50%)
    inter_percs = [0.5, ] + np.concatenate(inter_percs).tolist()
    # Get percentiles; they go along the last axis
    if filter:
        rv = [
            kale.utils.quantiles(vv[vv > 0.0], percs=inter_percs, weights=weights)
            for vv in vals
        ]
        rv = np.asarray(rv)
    else:
        rv = kale.utils.quantiles(vals, percs=inter_percs, weights=weights, axis=-1)

    med, *conf = rv.T
    # plot median
    hh, = ax.plot(xx, med, **plot, lw=lw, ls=ls, label=label)

    # Reshape confidence intervals to nice plotting shape
    # 2*P, X ==> (P, 2, X)
    conf = np.array(conf).reshape(len(percs), 2, xx.size)

    kw = dict(color=hh.get_color())
    kw.update(fill)
    fill = kw

    # plot each confidence interval
    for lo, hi in conf:
        gg = ax.fill_between(xx, lo, hi, **fill)

    return (hh, gg)

# %%
LABEL_GW_FREQUENCY_YR = r"GW Frequency $[\mathrm{yr}^{-1}]$"
LABEL_GW_FREQUENCY_HZ = r"GW Frequency $[\mathrm{Hz}]$"
LABEL_GW_FREQUENCY_NHZ = r"GW Frequency $[\mathrm{nHz}]$"
LABEL_SEPARATION_PC = r"Binary Separation $[\mathrm{pc}]$"
LABEL_CHARACTERISTIC_STRAIN = r"GW Characteristic Strain"
LABEL_HARDENING_TIME = r"Hardening Time $[\mathrm{Gyr}]$"
LABEL_CLC0 = r"$C_\ell / C_0$"

fig, ax = plot.figax(
    xlabel=LABEL_GW_FREQUENCY_YR,
    ylabel=LABEL_CHARACTERISTIC_STRAIN
)

frac = 0.50

xx = freqs * YR
__draw_gwb(ax, xx, gwb_sam, nsamp=0, color='k', label='SAM',lw=3,fracs=[frac])
#__draw_gwb(ax, xx, gwb_sam, nsamp=0, color='k', label='SAM (GPF+GMT)',lw=2)
#__draw_gwb(ax, xx, gwb_sam_no_gpf, nsamp=0, color='m', label='SAM (GMR)')
#color = ['darkgreen','purple']
#lw = [
#for d in all_fsa_dpops:
#__draw_gwb(ax, xx, all_fsa_dpops[0].gwb.both, nsamp=0, color=color[0], label=all_fsa_dpops[0].lbl,lw=1.5)
if len(all_dpops)>0:
    xx = all_dpops[0].freqs * YR
    print(f"{xx.size=}, {gwb_sam.shape=}")
    __draw_gwb(ax, xx, all_dpops[0].gwb.both, nsamp=0, color='g', 
               label=all_dpops[0].lbl,lw=1.5,fracs=[frac])
if len(all_dpops)>1:
    xx = all_dpops[1].freqs * YR
    __draw_gwb(ax, xx, all_dpops[1].gwb.both, nsamp=0, color='m', 
               label=all_dpops[1].lbl,lw=1.5,fracs=[frac])


if len(all_fsa_dpops)>0:
    xx = all_fsa_dpops[0].freqs * YR
    print(f"{xx.size=}, {gwb_sam.shape=}")
    print(f"{all_fsa_dpops[0].gwb.both.shape=}")
    __draw_gwb(ax, xx, all_fsa_dpops[0].gwb.both, nsamp=0, color='darkgreen', 
               label=all_fsa_dpops[0].lbl,lw=2,ls='--',fracs=[frac])
if len(all_fsa_dpops)>1:
    xx = all_fsa_dpops[1].freqs * YR
    print(f"{all_fsa_dpops[1].gwb.both.shape=}")
    __draw_gwb(ax, xx, all_fsa_dpops[1].gwb.both, nsamp=0, color='purple', 
               label=all_fsa_dpops[1].lbl,lw=2,ls='--',fracs=[frac])

plt.legend(loc='lower left',fontsize=12)
plt.savefig('gwb_compare_ill_tng100_main.png',dpi=300)

# %%
fig = holo.plot.plot_gwb(freqs, gwb_sam_new)

# %%
fig = holo.plot.plot_gwb(freqs, gwb_sam)

# %%
fig = holo.plot.plot_gwb(freqs, gwb_sam_no_gpf)
