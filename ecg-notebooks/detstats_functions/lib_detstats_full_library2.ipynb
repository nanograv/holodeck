# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import scipy as sp
import h5py

import holodeck as holo
import holodeck.single_sources as ss
from holodeck.constants import YR, MSOL
from holodeck import utils, detstats, plot


import hasasia.sensitivity as hsen
import hasasia.sim as hsim

# %% [markdown]
# # Plotting functions

# %%
def plot_sample_nn(fobs, hc_ss, hc_bg, dp_ss, dp_bg, df_ss, df_bg, nn):
    """ Plot strain and detection probability for a single sample.
    """
    shape = hc_ss.shape
    F, R, L = shape[0], shape[1], shape[2]
    S = dp_ss.shape[-1]
    fig, axs = plt.subplots(1, 2,figsize=(12,4))

    # Strains
    plot.draw_ss_and_gwb(axs[0], fobs*YR, hc_ss, hc_bg)
    axs[0].set_xlabel(plot.LABEL_GW_FREQUENCY_YR)
    axs[0].set_ylabel(plot.LABEL_CHARACTERISTIC_STRAIN)
    axs[0].set_title('Sample nn=%d (F=%d, R=%d, L=%d)' % (nn, F, R, L))
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')

    for ss in range(S):
        axs[1].scatter(np.arange(nreals), dp_ss[:,ss], alpha=0.25)
    axs[1].scatter(np.arange(nreals), dp_bg, color='k', 
                   label='BG, DF = %.2e' % df_bg,
                   marker='d')
    axs[1].errorbar(np.arange(nreals), np.mean(dp_ss[:,:], axis=1),
                     yerr = np.std(dp_ss[:,:], axis=1), color='orangered',
                      label = 'SS, sky-avg, DF = %.2e' % df_ss, linestyle='', capsize=3,
                       marker='o' )
    axs[1].set_xlabel('Realization (R)')
    axs[1].set_ylabel('SS DetProb')
    # axs[1].set_title('BG DF = ' %nn)
    fig.legend()
    fig.tight_layout()
    
    return fig
# nn=7
# fig = plot_sample_nn(fobs, hc_ss_all[nn], hc_bg_all[nn], 
#                      dp_ss_psr40[nn], dp_bg_psr40[nn],
#                      df_ss_psr40[nn], df_bg_psr40[nn], 
#                      nn)

# %%
def plot_detprob(dp_ss_all, dp_bg_all):
    """ Plot detection probability for many samples.

    Paramaters
    ----------
    dp_ss_all : (N,R) NDarray
    dp_bg_all : (N,R,S) NDarray
    """
    fig, ax = plt.subplots(figsize=(6.5,4))
    ax.set_xlabel('Param Space Sample')
    ax.set_ylabel('Detection Probability, $\gamma$')
    ax.errorbar(np.arange(nsamp), np.mean(dp_bg_all, axis=1), 
                yerr = np.std(dp_bg_all, axis=1), linestyle='', 
                marker='d', capsize=5, color='cornflowerblue', alpha=0.75,
                label = r'$\langle \gamma_\mathrm{BG} \rangle$')
    ax.errorbar(np.arange(nsamp), np.mean(dp_ss_all, axis=(1,2)),
                yerr = np.std(dp_ss_all, axis=(1,2)), linestyle='', 
                marker='o', capsize=5, color='orangered', alpha=0.75,
                label = r'$\langle \gamma_\mathrm{SS} \rangle$')
    ax.set_yscale('log')
    ax.set_title('Average DP across Realizations')

    ax.legend()
    fig.tight_layout()

    return fig

# fig = plot_detprob(dp_ss_all, dp_bg_all)

# %%
def plot_detfrac(df_ss, df_bg, thresh):
    fig, ax = plt.subplots(figsize=(6.5,4))
    ax.plot(np.arange(nsamp), df_bg, color='cornflowerblue', label='BG',
            marker='d')
    ax.plot(np.arange(nsamp), df_ss, color='orangered', label='SS',
            marker='o')
    ax.set_xlabel('Param Space Sample')
    ax.set_ylabel('Detection Fraction')
    ax.set_title('Fraction of Realizations with DP > %0.2f' % thresh)
    ax.legend()
    fig.tight_layout()
    return fig

# %%
def plot_nsample_dp(dp_ss, dp_bg, nn):
    fig, ax = plt.subplots(figsize=(6.5,4))
    for ss in range(nskies):
        ax.scatter(np.arange(nreals), dp_ss_psr40[nn,:,ss], alpha=0.5)
    ax.scatter(np.arange(nreals), dp_bg_psr40[nn], color='k')
    ax.set_xlabel('Realization (R)')
    ax.set_ylabel('SS DetProb')
    ax.set_title('Sample (N): %d' %nn)
    return fig
    

# fig = plot_nsample_dp(dp_ss_psr40, dp_bg_psr40, nn=7)
# fig = plot.plot_bg_ss(fobs, hc_bg_all[nn], hc_ss_all[nn])

# %% [markdown]
# ## Goal:
# Pass in an hdf5 file from a library of param spaces and return the average detection probability.
#
# ## Steps:
# 1) Read in file: fobs, hc_ss, hc_bg
# 2) Produce a PTA set-up calibrated to 50% hc_bg DP?
# 3) Given pulsar setup and hdf file, calculate average ss DP and average bg DP
#     * Calculate bg DP for each of R strain realizations
#     * Build S sky realizations
#     * Calculate ss DP for each of S sky realizations for each of R strain realizations.

# %% [markdown]
# # Step 1. Read in hdf file

# %%
filepath = '/Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/'
filename = filepath+'ss_lib.hdf5'
ssfile = h5py.File(filename, 'r')
print(list(ssfile.keys()))
# print(ssfile['pta_dur'][0])
fobs = ssfile['fobs'][:]
dfobs = ssfile['dfobs'][:]
dur = ssfile['pta_dur'][0]
cad = ssfile['pta_cad'][0]
hc_ss_all = ssfile['hc_ss'][...]
hc_bg_all = ssfile['hc_bg'][...]
shape = hc_ss_all.shape
nsamp, nfreqs, nreals, nloudest = shape[0], shape[1], shape[2], shape[3]
print(nsamp, nfreqs, nreals, nloudest)
ssfile.close()
# Out:
# ['dfobs', 'fit_plaw', 'fit_plaw_med', 'fit_plaw_nbins', 'fit_turn', 'fit_turn_med', 'fit_turn_nbins', 'fobs', 'hc_bg', 'hc_ss', 'pta_cad', 'pta_dur', 'sample_params']
# 100 100 30 5

# %%
print('samples (N):', nsamp, '\nreals (R):', nreals, '\nN,F,R,L:', hc_ss_all.shape)
# Out:
# samples (N): 100
# reals (R): 30
# N,F,R,L: (100, 100, 30, 5)

# %% [markdown]
# # Step 2. Calibrate PTA??
# Skipping this, picking 40 psrs with sigma 1e-7

# %% [markdown]
# # Step 3. Build PTA, Build skies, Calculate DP, Calculate DF
# Step 2 was skipped, we didn't calibrate the PTA. Just built one randomly.

# %%
def run_psr_calculations_and_plot(hc_ss_all, hc_bg_all, npsrs, sigma, nskies = 25, thresh=0.5,
                                  detstatspath='./'):
    """ Calculate DPs for a set of randomly placed pulsars with the number and range given.

    Parameters
    ----------

    Returns
    -------
    
    """
    shape = hc_ss_all.shape
    nsamp, nfreqs, nreals, nloudest = shape[0], shape[1], shape[2], shape[3]

    # build PTA
    print('building psrs')
    phis = np.random.uniform(0, 2*np.pi, size = npsrs)
    thetas = np.random.uniform(np.pi/2, np.pi/2, size = npsrs)
    # sigmas = np.ones_like(phis)*sigma
    psrs = hsim.sim_pta(timespan=dur/YR, cad=1/(cad/YR), sigma=sigma,
                    phi=phis, theta=thetas)

     # Build ss skies
    print('building ss skies')
    theta_ss, phi_ss, Phi0_ss, iota_ss, psi_ss = _build_skies(nfreqs, nskies, nloudest)

    # Calculate DPs 
    print('calculating SS and BG detections probabilities')
    dp_bg_all = np.zeros((nsamp, nreals)) # (N,R)
    dp_ss_all = np.zeros((nsamp, nreals, nskies)) # (N,R,S)
    df_bg_all = np.zeros(nsamp)
    df_ss_all = np.zeros(nsamp)
    for nn in range(nsamp):
        print('on nn/N = %d/%d' % (nn,nsamp))
        dp_bg_all[nn,:] = detstats.detect_bg_pta(psrs, fobs, cad, hc_bg_all[nn])
        dp_ss_all[nn,:,:] = detstats.detect_ss_pta(psrs, cad, dur, fobs, dfobs,
                                                hc_ss_all[nn], hc_bg_all[nn],
                                                theta_ss=theta_ss, phi_ss=phi_ss, Phi0_ss=Phi0_ss,
                                                iota_ss=iota_ss, psi_ss=psi_ss)
        count_bg = 0
        count_ss = 0
        for rr in range(nreals):
            if (dp_bg_all[nn,rr] > thresh):
                count_bg += 1
            for ss in range(nskies):
                if (dp_ss_all[nn,rr,ss] > thresh):
                    count_ss += 1
        df_bg_all[nn] = count_bg/nreals
        df_ss_all[nn] = count_ss/(nreals*nskies)

        fig = plot_sample_nn(fobs, hc_ss_all[nn], hc_bg_all[nn],
                         dp_ss_all[nn], dp_bg_all[nn], 
                         df_ss_all[nn], df_bg_all[nn], nn=nn)
        fname = (detstatspath+'p%06d_detprob.png' % nn) # need to make this directory
        print(fname)
        fig.savefig(fname, dpi=100)
        plt.close(fig)

    return dp_ss_all, dp_bg_all, df_ss_all, df_bg_all



def _build_skies(nfreqs, nskies, nloudest):
    theta_ss = np.random.uniform(0, np.pi, size = nfreqs * nskies * nloudest).reshape(nfreqs, nskies, nloudest)
    phi_ss = np.random.uniform(0, 2*np.pi, size = theta_ss.size).reshape(theta_ss.shape)
    Phi0_ss = np.random.uniform(0,2*np.pi, size = theta_ss.size).reshape(theta_ss.shape)
    iota_ss = np.random.uniform(0,  np.pi, size = theta_ss.size).reshape(theta_ss.shape)
    psi_ss = np.random.uniform(0,   np.pi, size = theta_ss.size).reshape(theta_ss.shape)
    return theta_ss, phi_ss, Phi0_ss, iota_ss, psi_ss

# %%
dp_ss2, dp_bg2, df_ss2, df_bg2 = run_psr_calculations_and_plot(hc_ss_all, hc_bg_all, npsrs = 40, sigma = 5e-7, 
                         nskies = 25, detstatspath=filepath+'detstats2/') # this is a pretty optimistic pta
fig1 = plot_detprob(dp_ss2, dp_bg2)
fig2 = plot_detfrac(df_ss2, df_bg2)
# Out:
# building psrs
# building ss skies
# calculating SS and BG detections probabilities
# on nn/N = 0/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000000_detprob.png
# on nn/N = 1/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000001_detprob.png
# on nn/N = 2/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000002_detprob.png
# on nn/N = 3/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000003_detprob.png
# on nn/N = 4/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000004_detprob.png
# on nn/N = 5/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000005_detprob.png
# on nn/N = 6/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000006_detprob.png
# on nn/N = 7/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000007_detprob.png
# on nn/N = 8/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000008_detprob.png
# on nn/N = 9/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000009_detprob.png
# on nn/N = 10/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000010_detprob.png
# on nn/N = 11/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000011_detprob.png
# on nn/N = 12/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000012_detprob.png
# on nn/N = 13/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000013_detprob.png
# on nn/N = 14/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000014_detprob.png
# on nn/N = 15/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000015_detprob.png
# on nn/N = 16/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000016_detprob.png
# on nn/N = 17/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000017_detprob.png
# on nn/N = 18/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000018_detprob.png
# on nn/N = 19/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000019_detprob.png
# on nn/N = 20/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000020_detprob.png
# on nn/N = 21/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000021_detprob.png
# on nn/N = 22/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000022_detprob.png
# on nn/N = 23/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000023_detprob.png
# on nn/N = 24/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000024_detprob.png
# on nn/N = 25/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000025_detprob.png
# on nn/N = 26/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000026_detprob.png
# on nn/N = 27/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000027_detprob.png
# on nn/N = 28/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000028_detprob.png
# on nn/N = 29/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000029_detprob.png
# on nn/N = 30/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000030_detprob.png
# on nn/N = 31/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000031_detprob.png
# on nn/N = 32/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000032_detprob.png
# on nn/N = 33/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000033_detprob.png
# on nn/N = 34/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000034_detprob.png
# on nn/N = 35/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000035_detprob.png
# on nn/N = 36/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000036_detprob.png
# on nn/N = 37/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000037_detprob.png
# on nn/N = 38/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000038_detprob.png
# on nn/N = 39/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000039_detprob.png
# on nn/N = 40/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000040_detprob.png
# on nn/N = 41/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000041_detprob.png
# on nn/N = 42/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000042_detprob.png
# on nn/N = 43/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000043_detprob.png
# on nn/N = 44/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000044_detprob.png
# on nn/N = 45/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000045_detprob.png
# on nn/N = 46/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000046_detprob.png
# on nn/N = 47/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000047_detprob.png
# on nn/N = 48/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000048_detprob.png
# on nn/N = 49/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000049_detprob.png
# on nn/N = 50/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000050_detprob.png
# on nn/N = 51/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000051_detprob.png
# on nn/N = 52/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000052_detprob.png
# on nn/N = 53/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000053_detprob.png
# on nn/N = 54/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000054_detprob.png
# on nn/N = 55/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000055_detprob.png
# on nn/N = 56/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000056_detprob.png
# on nn/N = 57/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000057_detprob.png
# on nn/N = 58/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000058_detprob.png
# on nn/N = 59/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000059_detprob.png
# on nn/N = 60/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000060_detprob.png
# on nn/N = 61/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000061_detprob.png
# on nn/N = 62/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000062_detprob.png
# on nn/N = 63/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000063_detprob.png
# on nn/N = 64/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000064_detprob.png
# on nn/N = 65/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000065_detprob.png
# on nn/N = 66/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000066_detprob.png
# on nn/N = 67/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000067_detprob.png
# on nn/N = 68/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000068_detprob.png
# on nn/N = 69/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000069_detprob.png
# on nn/N = 70/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000070_detprob.png
# on nn/N = 71/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000071_detprob.png
# on nn/N = 72/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000072_detprob.png
# on nn/N = 73/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000073_detprob.png
# on nn/N = 74/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000074_detprob.png
# on nn/N = 75/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000075_detprob.png
# on nn/N = 76/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000076_detprob.png
# on nn/N = 77/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000077_detprob.png
# on nn/N = 78/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000078_detprob.png
# on nn/N = 79/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000079_detprob.png
# on nn/N = 80/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000080_detprob.png
# on nn/N = 81/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000081_detprob.png
# on nn/N = 82/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000082_detprob.png
# on nn/N = 83/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000083_detprob.png
# on nn/N = 84/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000084_detprob.png
# on nn/N = 85/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000085_detprob.png
# on nn/N = 86/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000086_detprob.png
# on nn/N = 87/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000087_detprob.png
# on nn/N = 88/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000088_detprob.png
# on nn/N = 89/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000089_detprob.png
# on nn/N = 90/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000090_detprob.png
# on nn/N = 91/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000091_detprob.png
# on nn/N = 92/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000092_detprob.png
# on nn/N = 93/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000093_detprob.png
# on nn/N = 94/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000094_detprob.png
# on nn/N = 95/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000095_detprob.png
# on nn/N = 96/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000096_detprob.png
# on nn/N = 97/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000097_detprob.png
# on nn/N = 98/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000098_detprob.png
# on nn/N = 99/100
# /Users/emigardiner/GWs/holodeck/output/2023-05-09-mbp-ss15_n100_r30_f100_d15_l5_p0/detstats2/p000099_detprob.png
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 dp_ss2, dp_bg2, df_ss2, df_bg2 = run_psr_calculations_and_plot(hc_ss_all, hc_bg_all, npsrs = 40, sigma = 5e-7,
#       2                          nskies = 25, detstatspath=filepath+'detstats2/') # this is a pretty optimistic pta
#       3 fig1 = plot_detprob(dp_ss2, dp_bg2)
# ----> 4 fig2 = plot_detfrac(df_ss2, df_bg2)
#
# TypeError: plot_detfrac() missing 1 required positional argument: 'thresh'

# %%
detstats_path = filepath+'/detstats/dp2_psrs40_sigma5e-7/'

fig1 = plot_detprob(dp_ss2, dp_bg2)
fig2 = plot_detfrac(df_ss2, df_bg2, thresh=0.5)
fig1.savefig(detstats_path+'allsamp_detprobs.png', dpi=300)
fig2.savefig(detstats_path+'allsamp_detfracs.png', dpi=300)
np.savez(detstats_path+'detstats.npz', dp_ss=dp_ss2, dp_bg=dp_bg2, 
         df_ss=df_ss2, df_bg=df_bg2)

# %%
'''
def _detfrac_from_reals(dp_ss_all, dp_bg_all, thresh=0.5):
    """ 
    Calculate how many realizations have a detections, to get 
    the detection probability for a sample.

    Parameters
    ----------
    dp_ss_all : (N, R, S) NDarray
    dp_bg_all : (N, R) NDarray
    thresh : scalar
        threshold DP to count as a detection

    Returns
    -------
    ss_detfrac : (N,) NDarray
        Fraction of realizations with an ss DP above thresh.
    bg_detfrac : (N,) NDarray
        Fraction of realizations with a bg DP above thresh.

    NOTE: With minimal effort this can be done without for loops, 
    just needs some count() and condition array things
    """
    nsamp = len(dp_ss_all)
    nreals = len(dp_ss_all[0])
    nskies = len(dp_ss_all[0,0])
    bg_detfrac = np.zeros(nsamp)
    ss_detfrac = np.zeros(nsamp)
    for nn in range(nsamp):
        count_bg = 0
        count_ss = 0
        for rr in range(nreals):
            if (dp_bg_all[nn,rr] > thresh):
                count_bg += 1
            for ss in range(nskies):
                if (dp_ss_all[nn,rr,ss] > thresh):
                    count_ss += 1
        bg_detfrac[nn] = count_bg/nreals
        ss_detfrac[nn] = count_ss/(nreals*nskies)

    return ss_detfrac, bg_detfrac
'''
